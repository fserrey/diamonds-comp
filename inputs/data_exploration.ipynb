# %%
import pandas as pd
import numpy as np
import statsmodels as stat
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
diamonds_train = pd.read_csv("./dataset/diamonds_train.csv")
diamonds_test = pd.read_csv("./dataset/diamonds_test.csv")

# %%
print(diamonds_train.shape)
print(diamonds_test.shape)
# Out:
# (40455, 10)
# (13485, 10)

# %% [markdown]
# ### Features
# 1. **id**: only for test & sample submission files, id for prediction sample identification
# 2.  **price**: price in USD
# 3.  **carat**: weight of the diamond
# 4. **cut**: quality of the cut (Fair, Good, Very Good, Premium, Ideal)

# %%
display(diamonds_train.head())
display(diamonds_test.head())
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
#    id  carat        cut color clarity  depth  table     x     y     z
# 0   0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1   1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2   2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3   3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4   4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19

# %%
sns.set(style='darkgrid')
a = sns.pairplot(diamonds_train);
